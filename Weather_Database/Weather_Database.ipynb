# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities= []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
           
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=07949912b6c45738d39b1cb6c66425b9

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
       
       
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | roald
# Processing Record 3 of Set 1 | nanortalik
# Processing Record 4 of Set 1 | sisimiut
# Processing Record 5 of Set 1 | antofagasta
# Processing Record 6 of Set 1 | batemans bay
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | ketchikan
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | hambantota
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | rajauri
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | falconara marittima
# Processing Record 21 of Set 1 | sovetskiy
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 1 | belyy yar
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | shimoda
# Processing Record 32 of Set 1 | zhigansk
# Processing Record 33 of Set 1 | nome
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | gari
# Processing Record 36 of Set 1 | krutinka
# Processing Record 37 of Set 1 | castro-urdiales
# Processing Record 38 of Set 1 | nyurba
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | sterling
# Processing Record 44 of Set 1 | chokurdakh
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | paita
# Processing Record 50 of Set 1 | sao filipe
# Processing Record 1 of Set 2 | sao miguel do araguaia
# Processing Record 2 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 2 | evensk
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | pareora
# Processing Record 6 of Set 2 | dzilam gonzalez
# Processing Record 7 of Set 2 | linjiang
# Processing Record 8 of Set 2 | opuwo
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | mersing
# Processing Record 11 of Set 2 | norilsk
# Processing Record 12 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 2 | kavaratti
# Processing Record 14 of Set 2 | kalakamati
# Processing Record 15 of Set 2 | pedernales
# Processing Record 16 of Set 2 | kelso
# Processing Record 17 of Set 2 | igarka
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | sitka
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | keffi
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | olga
# Processing Record 26 of Set 2 | sunrise manor
# Processing Record 27 of Set 2 | bulgan
# Processing Record 28 of Set 2 | namatanai
# Processing Record 29 of Set 2 | ostrovnoy
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | vadso
# Processing Record 32 of Set 2 | sacaseni
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | nguru
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | deep river
# Processing Record 37 of Set 2 | cururupu
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | simao
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | esna
# Processing Record 42 of Set 2 | qiqihar
# Processing Record 43 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | pedasi
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | charlestown
# Processing Record 6 of Set 3 | venustiano carranza
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | kamenka
# Processing Record 9 of Set 3 | vilhena
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | goodyear
# Processing Record 12 of Set 3 | goma
# Processing Record 13 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 3 | foindu
# Processing Record 15 of Set 3 | punta arenas
# Processing Record 16 of Set 3 | santa rosa
# Processing Record 17 of Set 3 | okhtyrka
# Processing Record 18 of Set 3 | kahului
# Processing Record 19 of Set 3 | nampula
# Processing Record 20 of Set 3 | kiama
# Processing Record 21 of Set 3 | huilong
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | klaksvik
# Processing Record 25 of Set 3 | port blair
# Processing Record 26 of Set 3 | bon accord
# Processing Record 27 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 28 of Set 3 | camocim
# Processing Record 29 of Set 3 | lincoln
# Processing Record 30 of Set 3 | vaini
# Processing Record 31 of Set 3 | berdigestyakh
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | vestmannaeyjar
# Processing Record 34 of Set 3 | muros
# Processing Record 35 of Set 3 | shitanjing
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | acarau
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | bubaque
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | naze
# Processing Record 45 of Set 3 | krasnoselkup
# Processing Record 46 of Set 3 | maldonado
# Processing Record 47 of Set 3 | hermanus
# Processing Record 48 of Set 3 | santa cruz
# Processing Record 49 of Set 3 | cherskiy
# Processing Record 50 of Set 3 | emerald
# Processing Record 1 of Set 4 | salinas
# Processing Record 2 of Set 4 | saurimo
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | lhuntshi
# City not found. Skipping...
# Processing Record 6 of Set 4 | laguna
# Processing Record 7 of Set 4 | yulara
# Processing Record 8 of Set 4 | savinka
# Processing Record 9 of Set 4 | aden
# Processing Record 10 of Set 4 | rotifunk
# Processing Record 11 of Set 4 | spassk
# Processing Record 12 of Set 4 | ati
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | skelleftea
# Processing Record 15 of Set 4 | anaconda
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | champerico
# Processing Record 18 of Set 4 | kyrylivka
# Processing Record 19 of Set 4 | cartagena del chaira
# Processing Record 20 of Set 4 | rocha
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | magan
# Processing Record 23 of Set 4 | grand gaube
# Processing Record 24 of Set 4 | wasilla
# Processing Record 25 of Set 4 | saldanha
# Processing Record 26 of Set 4 | lima
# Processing Record 27 of Set 4 | constitucion
# Processing Record 28 of Set 4 | kushmurun
# Processing Record 29 of Set 4 | marzuq
# Processing Record 30 of Set 4 | olafsvik
# Processing Record 31 of Set 4 | san patricio
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | bambanglipuro
# Processing Record 35 of Set 4 | gamboma
# Processing Record 36 of Set 4 | ponta do sol
# Processing Record 37 of Set 4 | ivanava
# Processing Record 38 of Set 4 | te anau
# Processing Record 39 of Set 4 | staicele
# Processing Record 40 of Set 4 | provideniya
# Processing Record 41 of Set 4 | vila
# Processing Record 42 of Set 4 | maple valley
# Processing Record 43 of Set 4 | matagami
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | gazanjyk
# Processing Record 46 of Set 4 | cockburn town
# Processing Record 47 of Set 4 | partizanskoye
# Processing Record 48 of Set 4 | airai
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | basco
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | kolokani
# Processing Record 3 of Set 5 | mount gambier
# Processing Record 4 of Set 5 | luderitz
# Processing Record 5 of Set 5 | tiksi
# Processing Record 6 of Set 5 | punjai puliyampatti
# Processing Record 7 of Set 5 | saint-henri-de-levis
# City not found. Skipping...
# Processing Record 8 of Set 5 | akyab
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | vostok
# Processing Record 11 of Set 5 | geraldton
# Processing Record 12 of Set 5 | tura
# Processing Record 13 of Set 5 | barkhan
# Processing Record 14 of Set 5 | mandalgovi
# Processing Record 15 of Set 5 | akcaabat
# Processing Record 16 of Set 5 | gazli
# Processing Record 17 of Set 5 | ambilobe
# Processing Record 18 of Set 5 | shiyan
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | kaitangata
# Processing Record 21 of Set 5 | christchurch
# Processing Record 22 of Set 5 | parabel
# Processing Record 23 of Set 5 | amuntai
# Processing Record 24 of Set 5 | tutoia
# Processing Record 25 of Set 5 | gardner
# Processing Record 26 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 5 | maceio
# Processing Record 28 of Set 5 | havoysund
# Processing Record 29 of Set 5 | eyl
# Processing Record 30 of Set 5 | camopi
# Processing Record 31 of Set 5 | xining
# Processing Record 32 of Set 5 | syracuse
# Processing Record 33 of Set 5 | luganville
# Processing Record 34 of Set 5 | caninde de sao francisco
# Processing Record 35 of Set 5 | paamiut
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | coos bay
# Processing Record 38 of Set 5 | bambous virieux
# Processing Record 39 of Set 5 | victoria
# Processing Record 40 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 5 | masallatah
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | bang saphan
# Processing Record 45 of Set 5 | west plains
# Processing Record 46 of Set 5 | parana
# Processing Record 47 of Set 5 | horqueta
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | khash
# Processing Record 50 of Set 5 | srednekolymsk
# Processing Record 1 of Set 6 | las cruces
# Processing Record 2 of Set 6 | pochutla
# Processing Record 3 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 6 | huarmey
# Processing Record 5 of Set 6 | santa maria
# Processing Record 6 of Set 6 | qaqortoq
# Processing Record 7 of Set 6 | bullhead city
# Processing Record 8 of Set 6 | saint-francois
# Processing Record 9 of Set 6 | ajuchitlan
# Processing Record 10 of Set 6 | boa vista
# Processing Record 11 of Set 6 | platanos
# Processing Record 12 of Set 6 | noumea
# Processing Record 13 of Set 6 | narsaq
# Processing Record 14 of Set 6 | mzimba
# Processing Record 15 of Set 6 | vardo
# Processing Record 16 of Set 6 | tiznit
# Processing Record 17 of Set 6 | yevlax
# Processing Record 18 of Set 6 | talcahuano
# Processing Record 19 of Set 6 | dabakala
# Processing Record 20 of Set 6 | kruisfontein
# Processing Record 21 of Set 6 | guaruja
# Processing Record 22 of Set 6 | aksu
# Processing Record 23 of Set 6 | upernavik
# Processing Record 24 of Set 6 | tigre
# Processing Record 25 of Set 6 | andenes
# Processing Record 26 of Set 6 | fort nelson
# Processing Record 27 of Set 6 | wala
# Processing Record 28 of Set 6 | hay river
# Processing Record 29 of Set 6 | monte alegre
# Processing Record 30 of Set 6 | lompoc
# Processing Record 31 of Set 6 | beringovskiy
# Processing Record 32 of Set 6 | bonavista
# Processing Record 33 of Set 6 | cidreira
# Processing Record 34 of Set 6 | redmond
# Processing Record 35 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 6 | berezna
# Processing Record 37 of Set 6 | sosnovo-ozerskoye
# Processing Record 38 of Set 6 | kandi
# Processing Record 39 of Set 6 | yabrud
# Processing Record 40 of Set 6 | san quintin
# Processing Record 41 of Set 6 | luangwa
# Processing Record 42 of Set 6 | zapolyarnyy
# Processing Record 43 of Set 6 | sauda
# Processing Record 44 of Set 6 | abohar
# Processing Record 45 of Set 6 | gardendale
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | faya
# Processing Record 48 of Set 6 | khalki
# Processing Record 49 of Set 6 | iqaluit
# Processing Record 50 of Set 6 | vila velha
# Processing Record 1 of Set 7 | makakilo city
# Processing Record 2 of Set 7 | anamur
# Processing Record 3 of Set 7 | haines junction
# Processing Record 4 of Set 7 | xinqing
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | egersund
# Processing Record 7 of Set 7 | yarmouth
# Processing Record 8 of Set 7 | port macquarie
# Processing Record 9 of Set 7 | isangel
# Processing Record 10 of Set 7 | port-cartier
# Processing Record 11 of Set 7 | padang
# Processing Record 12 of Set 7 | marsh harbour
# Processing Record 13 of Set 7 | aquiraz
# Processing Record 14 of Set 7 | oussouye
# Processing Record 15 of Set 7 | bilibino
# Processing Record 16 of Set 7 | athabasca
# Processing Record 17 of Set 7 | shu
# Processing Record 18 of Set 7 | weyburn
# Processing Record 19 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 7 | prince rupert
# Processing Record 21 of Set 7 | hun
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | puerto madero
# Processing Record 24 of Set 7 | tuatapere
# Processing Record 25 of Set 7 | saint anthony
# Processing Record 26 of Set 7 | baculin
# Processing Record 27 of Set 7 | kedrovyy
# Processing Record 28 of Set 7 | carutapera
# Processing Record 29 of Set 7 | plavinas
# Processing Record 30 of Set 7 | plettenberg bay
# Processing Record 31 of Set 7 | severo-yeniseyskiy
# Processing Record 32 of Set 7 | fare
# Processing Record 33 of Set 7 | niquelandia
# Processing Record 34 of Set 7 | oriximina
# Processing Record 35 of Set 7 | gombong
# Processing Record 36 of Set 7 | dire
# Processing Record 37 of Set 7 | bandarbeyla
# Processing Record 38 of Set 7 | gao
# Processing Record 39 of Set 7 | pajapan
# Processing Record 40 of Set 7 | mecca
# Processing Record 41 of Set 7 | carballo
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 44 of Set 7 | viedma
# Processing Record 45 of Set 7 | inhambane
# Processing Record 46 of Set 7 | timaru
# Processing Record 47 of Set 7 | seoul
# Processing Record 48 of Set 7 | bushehr
# Processing Record 49 of Set 7 | najran
# Processing Record 50 of Set 7 | mitchell
# Processing Record 1 of Set 8 | vallenar
# Processing Record 2 of Set 8 | seminole
# Processing Record 3 of Set 8 | huangzhai
# Processing Record 4 of Set 8 | olinda
# Processing Record 5 of Set 8 | tatawin
# Processing Record 6 of Set 8 | tateyama
# Processing Record 7 of Set 8 | ausa
# Processing Record 8 of Set 8 | pouebo
# Processing Record 9 of Set 8 | kualakapuas
# Processing Record 10 of Set 8 | morondava
# Processing Record 11 of Set 8 | gonaives
# Processing Record 12 of Set 8 | ullubiyaul
# Processing Record 13 of Set 8 | yablonovo
# Processing Record 14 of Set 8 | amalapuram
# Processing Record 15 of Set 8 | salalah
# Processing Record 16 of Set 8 | zvishavane
# Processing Record 17 of Set 8 | ratnagiri
# Processing Record 18 of Set 8 | burnie
# Processing Record 19 of Set 8 | matadi
# Processing Record 20 of Set 8 | alta floresta
# Processing Record 21 of Set 8 | tezu
# Processing Record 22 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 8 | pontianak
# Processing Record 24 of Set 8 | chase
# Processing Record 25 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 8 | betulia
# Processing Record 27 of Set 8 | marrakesh
# Processing Record 28 of Set 8 | longonjo
# Processing Record 29 of Set 8 | preobrazheniye
# Processing Record 30 of Set 8 | koundara
# Processing Record 31 of Set 8 | beloha
# Processing Record 32 of Set 8 | bethal
# Processing Record 33 of Set 8 | narasannapeta
# Processing Record 34 of Set 8 | burica
# City not found. Skipping...
# Processing Record 35 of Set 8 | termoli
# Processing Record 36 of Set 8 | ruteng
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | mulki
# Processing Record 39 of Set 8 | westport
# Processing Record 40 of Set 8 | bria
# Processing Record 41 of Set 8 | vieux-habitants
# Processing Record 42 of Set 8 | severnyy
# Processing Record 43 of Set 8 | turukhansk
# Processing Record 44 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | praia da vitoria
# Processing Record 46 of Set 8 | asekeyevo
# Processing Record 47 of Set 8 | cayenne
# Processing Record 48 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 49 of Set 8 | berlevag
# Processing Record 50 of Set 8 | beidao
# Processing Record 1 of Set 9 | cervo
# Processing Record 2 of Set 9 | birjand
# Processing Record 3 of Set 9 | havelock
# Processing Record 4 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 9 | whyalla
# Processing Record 6 of Set 9 | malartic
# Processing Record 7 of Set 9 | kavieng
# Processing Record 8 of Set 9 | capilla de guadalupe
# Processing Record 9 of Set 9 | richards bay
# Processing Record 10 of Set 9 | huntsville
# Processing Record 11 of Set 9 | lac du bonnet
# Processing Record 12 of Set 9 | maningrida
# Processing Record 13 of Set 9 | lorengau
# Processing Record 14 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 9 | hualmay
# Processing Record 16 of Set 9 | melita
# Processing Record 17 of Set 9 | fortuna
# Processing Record 18 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 9 | coihaique
# Processing Record 20 of Set 9 | lermontovka
# Processing Record 21 of Set 9 | brae
# Processing Record 22 of Set 9 | sorkjosen
# Processing Record 23 of Set 9 | solnechnyy
# Processing Record 24 of Set 9 | almaznyy
# Processing Record 25 of Set 9 | dukat
# Processing Record 26 of Set 9 | oranjestad
# Processing Record 27 of Set 9 | poum
# Processing Record 28 of Set 9 | chadiza
# Processing Record 29 of Set 9 | mantua
# Processing Record 30 of Set 9 | warmbad
# Processing Record 31 of Set 9 | fairbanks
# Processing Record 32 of Set 9 | port lincoln
# Processing Record 33 of Set 9 | alofi
# Processing Record 34 of Set 9 | hyeres
# Processing Record 35 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 9 | wanxian
# Processing Record 37 of Set 9 | nabire
# Processing Record 38 of Set 9 | kirensk
# Processing Record 39 of Set 9 | kubachi
# Processing Record 40 of Set 9 | samarai
# Processing Record 41 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 9 | batagay-alyta
# Processing Record 43 of Set 9 | uvat
# Processing Record 44 of Set 9 | davila
# Processing Record 45 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 9 | bogorodskoye
# Processing Record 47 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | shelburne
# Processing Record 50 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 1 of Set 10 | hailey
# Processing Record 2 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 10 | mayo
# Processing Record 4 of Set 10 | clyde river
# Processing Record 5 of Set 10 | namibe
# Processing Record 6 of Set 10 | port hedland
# Processing Record 7 of Set 10 | burpengary
# Processing Record 8 of Set 10 | palermo
# Processing Record 9 of Set 10 | ulaanbaatar
# Processing Record 10 of Set 10 | bonthe
# Processing Record 11 of Set 10 | itarema
# Processing Record 12 of Set 10 | aklavik
# Processing Record 13 of Set 10 | yuryevets
# Processing Record 14 of Set 10 | lasa
# Processing Record 15 of Set 10 | tazlar
# Processing Record 16 of Set 10 | hudiksvall
# Processing Record 17 of Set 10 | the valley
# Processing Record 18 of Set 10 | muzhi
# Processing Record 19 of Set 10 | arak
# Processing Record 20 of Set 10 | sholokhovskiy
# Processing Record 21 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 10 | sorland
# Processing Record 23 of Set 10 | partenit
# Processing Record 24 of Set 10 | vilani
# Processing Record 25 of Set 10 | tabuk
# Processing Record 26 of Set 10 | izhma
# Processing Record 27 of Set 10 | carnduff
# Processing Record 28 of Set 10 | ndjole
# Processing Record 29 of Set 10 | pudozh
# Processing Record 30 of Set 10 | nossa senhora da gloria
# Processing Record 31 of Set 10 | canico
# Processing Record 32 of Set 10 | waipawa
# Processing Record 33 of Set 10 | rafaela
# Processing Record 34 of Set 10 | novobirilyussy
# Processing Record 35 of Set 10 | nuevitas
# Processing Record 36 of Set 10 | alihe
# Processing Record 37 of Set 10 | pandan
# Processing Record 38 of Set 10 | jalu
# Processing Record 39 of Set 10 | margate
# Processing Record 40 of Set 10 | oistins
# Processing Record 41 of Set 10 | devyatka
# City not found. Skipping...
# Processing Record 42 of Set 10 | prainha
# Processing Record 43 of Set 10 | sabha
# Processing Record 44 of Set 10 | valdez
# Processing Record 45 of Set 10 | staryy nadym
# Processing Record 46 of Set 10 | touros
# Processing Record 47 of Set 10 | pindiga
# Processing Record 48 of Set 10 | old road
# City not found. Skipping...
# Processing Record 49 of Set 10 | hobyo
# Processing Record 50 of Set 10 | deputatskiy
# Processing Record 1 of Set 11 | litovko
# Processing Record 2 of Set 11 | los lunas
# Processing Record 3 of Set 11 | college
# Processing Record 4 of Set 11 | pacific grove
# Processing Record 5 of Set 11 | taloqan
# Processing Record 6 of Set 11 | beterou
# Processing Record 7 of Set 11 | antropovo
# Processing Record 8 of Set 11 | taltal
# Processing Record 9 of Set 11 | labuhan
# Processing Record 10 of Set 11 | huai yot
# Processing Record 11 of Set 11 | mildura
# Processing Record 12 of Set 11 | kutum
# Processing Record 13 of Set 11 | general roca
# Processing Record 14 of Set 11 | verkhnevilyuysk
# Processing Record 15 of Set 11 | carstairs
# Processing Record 16 of Set 11 | killini
# City not found. Skipping...
# Processing Record 17 of Set 11 | honiara
# Processing Record 18 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 11 | pishva
# Processing Record 20 of Set 11 | zhuhai
# Processing Record 21 of Set 11 | kulhudhuffushi
# Processing Record 22 of Set 11 | tuskegee
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | peski
# Processing Record 25 of Set 11 | kushima
# Processing Record 26 of Set 11 | jatai
# Processing Record 27 of Set 11 | nushki
# Processing Record 28 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 11 | rawson
# Processing Record 30 of Set 11 | djenne
# Processing Record 31 of Set 11 | arlit
# Processing Record 32 of Set 11 | husavik
# Processing Record 33 of Set 11 | yerbogachen
# Processing Record 34 of Set 11 | dalby
# Processing Record 35 of Set 11 | lagoa
# Processing Record 36 of Set 11 | pervoye maya
# Processing Record 37 of Set 11 | aktau
# Processing Record 38 of Set 11 | hohhot
# Processing Record 39 of Set 11 | coroico
# Processing Record 40 of Set 11 | springdale
# Processing Record 41 of Set 11 | morropon
# Processing Record 42 of Set 11 | girau do ponciano
# Processing Record 43 of Set 11 | basoko
# Processing Record 44 of Set 11 | keuruu
# Processing Record 45 of Set 11 | baykit
# Processing Record 46 of Set 11 | villa rica
# Processing Record 47 of Set 11 | avera
# Processing Record 48 of Set 11 | mehamn
# Processing Record 49 of Set 11 | bira
# Processing Record 50 of Set 11 | alanya
# Processing Record 1 of Set 12 | dawlatabad
# Processing Record 2 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 12 | awbari
# Processing Record 4 of Set 12 | santiago
# Processing Record 5 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 12 | nizwa
# Processing Record 7 of Set 12 | firozpur jhirka
# Processing Record 8 of Set 12 | robertsport
# Processing Record 9 of Set 12 | katangli
# Processing Record 10 of Set 12 | paciran
# Processing Record 11 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 12 | caarapo
# Processing Record 13 of Set 12 | san joaquin
# Processing Record 14 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 12 | sechura
# Processing Record 16 of Set 12 | fort-shevchenko
# Processing Record 17 of Set 12 | la paz
# Processing Record 18 of Set 12 | atasu
# Processing Record 19 of Set 12 | raga
# Processing Record 20 of Set 12 | mabaruma
# Processing Record 21 of Set 12 | pamanukan
# Processing Record 22 of Set 12 | teahupoo
# Processing Record 23 of Set 12 | sur
# Processing Record 24 of Set 12 | chitungwiza
# Processing Record 25 of Set 12 | labytnangi
# Processing Record 26 of Set 12 | kieta
# Processing Record 27 of Set 12 | wake forest
# Processing Record 28 of Set 12 | humberto de campos
# Processing Record 29 of Set 12 | mataram
# Processing Record 30 of Set 12 | port-gentil
# Processing Record 31 of Set 12 | puerto madryn
# Processing Record 32 of Set 12 | kirakira
# Processing Record 33 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 12 | keetmanshoop
# Processing Record 35 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 12 | kroya
# Processing Record 37 of Set 12 | tymovskoye
# Processing Record 38 of Set 12 | goderich
# Processing Record 39 of Set 12 | taguatinga
# Processing Record 40 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 12 | merauke
# Processing Record 42 of Set 12 | nishihara
# Processing Record 43 of Set 12 | darnah
# Processing Record 44 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 12 | yar-sale
# Processing Record 46 of Set 12 | sungaipenuh
# Processing Record 47 of Set 12 | harper
# Processing Record 48 of Set 12 | u thong
# Processing Record 49 of Set 12 | clinton
# Processing Record 50 of Set 12 | tautira
# Processing Record 1 of Set 13 | tenkodogo
# Processing Record 2 of Set 13 | igrim
# Processing Record 3 of Set 13 | bani walid
# Processing Record 4 of Set 13 | san cristobal
# Processing Record 5 of Set 13 | hammerfest
# Processing Record 6 of Set 13 | sao jose da coroa grande
# Processing Record 7 of Set 13 | calvinia
# Processing Record 8 of Set 13 | belmonte
# Processing Record 9 of Set 13 | port augusta
# Processing Record 10 of Set 13 | turbat
# Processing Record 11 of Set 13 | balashov
# Processing Record 12 of Set 13 | half moon bay
# Processing Record 13 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 13 | trelew
# Processing Record 15 of Set 13 | gyongyostarjan
# Processing Record 16 of Set 13 | baglan
# Processing Record 17 of Set 13 | benemerito de las americas
# Processing Record 18 of Set 13 | formosa
# Processing Record 19 of Set 13 | goba
# Processing Record 20 of Set 13 | vanavara
# Processing Record 21 of Set 13 | cessnock
# Processing Record 22 of Set 13 | saint-pierre
# Processing Record 23 of Set 13 | alugan
# Processing Record 24 of Set 13 | wuning
# Processing Record 25 of Set 13 | karratha
# Processing Record 26 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 27 of Set 13 | santa maria del oro
# Processing Record 28 of Set 13 | midland
# Processing Record 29 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 30 of Set 13 | bara
# Processing Record 31 of Set 13 | severomuysk
# Processing Record 32 of Set 13 | henties bay
# Processing Record 33 of Set 13 | agnibilekrou
# Processing Record 34 of Set 13 | carbonia
# Processing Record 35 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 13 | nuuk
# Processing Record 37 of Set 13 | anadyr
# Processing Record 38 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 13 | corinto
# Processing Record 40 of Set 13 | sinnamary
# Processing Record 41 of Set 13 | novoagansk
# Processing Record 42 of Set 13 | esperanza
# Processing Record 43 of Set 13 | san carlos de bariloche
# Processing Record 44 of Set 13 | ntoum
# Processing Record 45 of Set 13 | taoudenni
# Processing Record 46 of Set 13 | norman
# Processing Record 47 of Set 13 | nantucket
# Processing Record 48 of Set 13 | barranca
# Processing Record 49 of Set 13 | glossa
# Processing Record 50 of Set 13 | marystown
# Processing Record 1 of Set 14 | pirajui
# Processing Record 2 of Set 14 | daltenganj
# Processing Record 3 of Set 14 | grass valley
# Processing Record 4 of Set 14 | neuquen
# Processing Record 5 of Set 14 | avanigadda
# Processing Record 6 of Set 14 | hovd
# Processing Record 7 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 14 | surt
# Processing Record 10 of Set 14 | katobu
# Processing Record 11 of Set 14 | la plata
# Processing Record 12 of Set 14 | milkovo
# Processing Record 13 of Set 14 | acapulco
# Processing Record 14 of Set 14 | chama
# Processing Record 15 of Set 14 | lata
# Processing Record 16 of Set 14 | sibu
# Processing Record 17 of Set 14 | america dourada
# Processing Record 18 of Set 14 | ukiah
# Processing Record 19 of Set 14 | manggar
# Processing Record 20 of Set 14 | meulaboh
# Processing Record 21 of Set 14 | morris
# Processing Record 22 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 14 | itinga
# Processing Record 24 of Set 14 | tawzar
# City not found. Skipping...
# Processing Record 25 of Set 14 | axim
# Processing Record 26 of Set 14 | marawi
# Processing Record 27 of Set 14 | yemtsa
# Processing Record 28 of Set 14 | waverly
# Processing Record 29 of Set 14 | gigmoto
# Processing Record 30 of Set 14 | ankazobe
# Processing Record 31 of Set 14 | mount isa
# Processing Record 32 of Set 14 | itupiranga
# Processing Record 33 of Set 14 | popondetta
# Processing Record 34 of Set 14 | klyuchi
# Processing Record 35 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 37 of Set 14 | storforshei
# Processing Record 38 of Set 14 | batangafo
# Processing Record 39 of Set 14 | urucara
# Processing Record 40 of Set 14 | borogontsy
# Processing Record 41 of Set 14 | hervey bay
# Processing Record 42 of Set 14 | monrovia
# Processing Record 43 of Set 14 | las tunas
# Processing Record 44 of Set 14 | jelgava
# Processing Record 45 of Set 14 | bilma
# Processing Record 46 of Set 14 | sarangani
# Processing Record 47 of Set 14 | humaita
# Processing Record 48 of Set 14 | orcopampa
# Processing Record 49 of Set 14 | vakhrushev
# Processing Record 50 of Set 14 | san angelo
# Processing Record 1 of Set 15 | caravelas
# Processing Record 2 of Set 15 | chicama
# Processing Record 3 of Set 15 | lydenburg
# Processing Record 4 of Set 15 | qasigiannguit
# Processing Record 5 of Set 15 | porto walter
# Processing Record 6 of Set 15 | lagos
# Processing Record 7 of Set 15 | bayangol
# Processing Record 8 of Set 15 | pingliang
# Processing Record 9 of Set 15 | sucha beskidzka
# Processing Record 10 of Set 15 | kaeo
# Processing Record 11 of Set 15 | san jose
# Processing Record 12 of Set 15 | mitsamiouli
# Processing Record 13 of Set 15 | puerto escondido
# Processing Record 14 of Set 15 | phangnga
# Processing Record 15 of Set 15 | stornoway
# Processing Record 16 of Set 15 | razole
# Processing Record 17 of Set 15 | atambua
# Processing Record 18 of Set 15 | shellbrook
# Processing Record 19 of Set 15 | ceuta
# Processing Record 20 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 15 | broken hill
# Processing Record 22 of Set 15 | abengourou
# Processing Record 23 of Set 15 | batagay
# Processing Record 24 of Set 15 | kurilsk
# Processing Record 25 of Set 15 | pingzhuang
# Processing Record 26 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 27 of Set 15 | madera
# Processing Record 28 of Set 15 | lazurne
# Processing Record 29 of Set 15 | pyaozerskiy
# Processing Record 30 of Set 15 | betsiamites
# Processing Record 31 of Set 15 | akora
# Processing Record 32 of Set 15 | saint-pie
# Processing Record 33 of Set 15 | ozu
# Processing Record 34 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 15 | dudinka
# Processing Record 36 of Set 15 | upata
# Processing Record 37 of Set 15 | port hardy
# Processing Record 38 of Set 15 | togur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 671

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   East London -33.0153   27.9116     62.64        70         100
# 1         Roald  62.5833    6.1333     57.33        87         100
# 2    Nanortalik  60.1432  -45.2371     36.37        74           5
# 3      Sisimiut  66.9395  -53.6735     31.60        84         100
# 4   Antofagasta -23.6500  -70.4000     58.28        75          25
# 5  Batemans Bay -35.7167  150.1833     65.10        56          81
# 6     Busselton -33.6500  115.3333     59.76        63           0
# 7        Atuona  -9.8000 -139.0333     76.39        78          28
# 8     Mahebourg -20.4081   57.7000     70.25        78          20
# 9     Ketchikan  55.3422 -131.6461     52.88        78          99
#
#    Wind Speed Country Current Description
# 0       14.67      ZA     overcast clouds
# 1       11.50      NO     overcast clouds
# 2        4.21      GL           clear sky
# 3        6.55      GL     overcast clouds
# 4        4.14      CL    scattered clouds
# 5        9.48      AU       broken clouds
# 6       13.33      AU           clear sky
# 7       19.46      PF    scattered clouds
# 8        6.91      MU          few clouds
# 9        4.29      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_df]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   East London      ZA -33.0153   27.9116     62.64        70         100
# 1         Roald      NO  62.5833    6.1333     57.33        87         100
# 2    Nanortalik      GL  60.1432  -45.2371     36.37        74           5
# 3      Sisimiut      GL  66.9395  -53.6735     31.60        84         100
# 4   Antofagasta      CL -23.6500  -70.4000     58.28        75          25
# 5  Batemans Bay      AU -35.7167  150.1833     65.10        56          81
# 6     Busselton      AU -33.6500  115.3333     59.76        63           0
# 7        Atuona      PF  -9.8000 -139.0333     76.39        78          28
# 8     Mahebourg      MU -20.4081   57.7000     70.25        78          20
# 9     Ketchikan      US  55.3422 -131.6461     52.88        78          99
#
#    Wind Speed Current Description
# 0       14.67     overcast clouds
# 1       11.50     overcast clouds
# 2        4.21           clear sky
# 3        6.55     overcast clouds
# 4        4.14    scattered clouds
# 5        9.48       broken clouds
# 6       13.33           clear sky
# 7       19.46    scattered clouds
# 8        6.91          few clouds
# 9        4.29     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data = "Weather_data.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data)

# %%
print(city_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9704\3038165769.py in <module>
# ----> 1 print(city_url)
#
# NameError: name 'city_url' is not defined
